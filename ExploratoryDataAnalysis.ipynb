# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.1

# %% [markdown]
# # Data
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# Read Titanic Dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b70dd66a-8287-43bf-be2d-75447ac829bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b70dd66a-8287-43bf-be2d-75447ac829bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
titanic_csv = 'titanic_train.csv'
titanic = pd.read_csv(titanic_csv)

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every step

# %% [markdown]
# ### Age

# %%
# ANSWER
# There are null values in the columns 'Age', 'Cabin', 'Embarked'
# Age can be replaced with the median to not skew the overall distribution of the data
titanic['Age'] = titanic['Age'].fillna(titanic['Age'].median())

# %% [markdown]
# ### Cabin

# %%
# ANSWER
# Cabin can be replaced with 'Unknown', since it is a string and shouldn't be replaced by a numerical value
titanic['Cabin'] = titanic['Cabin'].fillna('Unknown')

# %% [markdown]
# ### Embarked

# %%
# ANSWER
# Embarked can be replaced by the mode because the missing values are most likely going to be the mode
titanic['Embarked'] = titanic['Embarked'].fillna(titanic['Embarked'].mode()[0])

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
# ANSWER
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)

    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %% [markdown]
# ## Pclass
#
# Use the `bar_charts` function above to view the relationship between survived and pclass.  Note your findings.

# %%
# ANSWER
bar_charts(titanic, 'Pclass')
# Pclass number 3 had a significantly lower (2.5x) chance of surviving than not surviving.
# Similarly, pclass number 2 had a lower chance of surviving than not surviving, but not as much as pclass 3.
# Pclass number 1 had a higher chance of surviving than not living. Compared to the other 2 classes, it had the highest chance of surviving.

# %% [markdown]
# ## Sex
#
# Use `bar_charts` to view the relationship between survived and sex.  Note your findings.

# %%
# ANSWER
bar_charts(titanic, 'Sex')
# Females had a MUCH higher chance of surviving than males.

# %% [markdown]
# ## Parch
#
# Parch = Number of parents and children travelling with each passenger. Use `bar_charts` to view the relationship between survived and Parch.

# %%
# ANSWER
bar_charts(titanic, 'Parch')
# passengers with 0 parents/children had a higher chance of not survivng than surviving, but this alone doesn't reveal much insight as to whether it increased or decreased a passenger's chances of surviving.
# I need to analyse the other bars

# %%
# I want to try logging the y-axis to reveal more information. The function is the same as bar_charts(df, feature), but with an added line
def bar_charts_ylog(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)

    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.yscale('log')  # I have added this line
    plt.show();

bar_charts_ylog(titanic, 'Parch')
# This y-logged graph reveals that for a passenger, the higher the number of parents/children, the higher the chances of survival (but only up to 3)
# When parch > 3, the chances of survival decreased significantly.

# %% [markdown]
# ## SibSp
#
# SibSp = Number of siblings and spouses travelling with each passenger. Use `bar_charts` to view the relationship between survived and SibSp.

# %%
# ANSWER
# again, the chart is easier to analyse with y-log axis.
bar_charts_ylog(titanic, 'SibSp')
# It looks like the higher the number of siblings, the lower the chance of surviving, because the red, purple, brown, pink drop significantly from not surviving to surviving.

# %% [markdown]
# ## Embarked
#
# Do the same for the Embarked variable.

# %%
# ANSWER
bar_charts(titanic, 'Embarked')

# %% [markdown]
# # Feature Engineering
#
# We shall create some new features from the existing features.

# %% [markdown]
# ## Fare Class
#
# Create a new column 'Fare class' based on their fare as defined below. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
# ANSWER
titanic['Fare class'] = titanic['Fare'].apply(create_fare_class)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Fare class
# 0      0         A/5 21171   7.2500  Unknown        S           4
# 1      0          PC 17599  71.2833      C85        C           1
# 2      0  STON/O2. 3101282   7.9250  Unknown        S           4
# ...

# %% [markdown]
# ## Age Class
#
# Similarly, create a new column 'Age class' based on their age as defined below.

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
# ANSWER
titanic['Age class'] = titanic['Age'].apply(create_age_class)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Fare class  Age class
# 0      0         A/5 21171   7.2500  Unknown        S           4          2
# 1      0          PC 17599  71.2833      C85        C           1          4
# 2      0  STON/O2. 3101282   7.9250  Unknown        S           4          3
# ...

# %% [markdown]
# # Statistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
# ANSWER
titanic_for_correlation = titanic.drop(columns=['Cabin', 'Name', 'Ticket', 'PassengerId'])
titanic_for_correlation = pd.get_dummies(titanic_for_correlation, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
correlation_matrix = titanic_for_correlation.corr()
print(correlation_matrix)
# Out:
#             Survived       Age     SibSp     Parch      Fare  Fare class  \
# Survived    1.000000 -0.064910 -0.035322  0.081629  0.257307   -0.307600
# Age        -0.064910  1.000000 -0.233296 -0.172482  0.096688   -0.117248
# SibSp      -0.035322 -0.233296  1.000000  0.414838  0.159651   -0.380692
# Parch       0.081629 -0.172482  0.414838  1.000000  0.216225   -0.387100
# Fare        0.257307  0.096688  0.159651  0.216225  1.000000   -0.599129
# Fare class -0.307600 -0.117248 -0.380692 -0.387100 -0.599129    1.000000
# Age class  -0.067911  0.927548 -0.232166 -0.168121  0.075551   -0.080506
# Sex_male   -0.543351  0.081163 -0.114631 -0.245489 -0.182333    0.239309
# Embarked_Q  0.003650 -0.031415 -0.026354 -0.081228 -0.117216    0.208207
# Embarked_S -0.149683 -0.006729  0.068734  0.060814 -0.162184    0.054850
# Pclass_2    0.093349  0.015831 -0.055932 -0.000734 -0.118557   -0.093996
# Pclass_3   -0.322308 -0.291955  0.092548  0.015790 -0.413333    0.642768
#
# ...

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# The usual process of null hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the p-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the p-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data, one with passengers who survived and another one with passengers who died (call them `titanic_survived` and `titanic_died`). The sample sizes should ideally be the same but they can be different. Let's say that the sample sizes are 100.

# %%
N=100
# ANSWER
titanic_survived = titanic[titanic['Survived'] == 1]
titanic_died = titanic[titanic['Survived'] == 0]
titanic_survived_sampled = titanic_survived.sample(n=N, random_state=42)
titanic_died_sampled = titanic_died.sample(n=N, random_state=42)

# %%
a = titanic_survived_sampled['Age']
b = titanic_died_sampled['Age']

# %% [markdown]
# ### Set alpha (let alpha = 0.05)

# %%
# ANSWER
alpha = 0.05

# %% [markdown]
# ### Calculate test statistic
#
# > Here we identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
## Calculate the variance to get the standard deviation
var_a = a.var(ddof = 1)
var_b = b.var(ddof = 1)

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)

# %%
## Calculate the t-statistic
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))

# %% [markdown]
# ### Find the p-value
#
# > Next we compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*N - 2
from scipy import stats
#p-value after comparison with the t
if (t > 0):
    p = 2*(1 - stats.t.cdf(t, df = df))
else:
    p = 2*stats.t.cdf(t, df = df)

# %%
print("t = " + str(t))
print("p = " + str(p))
# Out:
# t = -1.6297892845822435
# p = 0.10473585981105664

# %% [markdown]
# ### Interpret results
#
# > The p-value is compared to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, then the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    else:
        print("We fail to reject our null hypothesis.")

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)
# Out:
# t = -1.6297892845822435
# p = 0.10473585981105664
# We fail to reject our null hypothesis.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2025 Institute of Data
#
#
# ---
#
#
#
# ---
